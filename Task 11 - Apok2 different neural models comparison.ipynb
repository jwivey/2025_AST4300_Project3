# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.table import Table

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# Age option 2 APOKASC-2 Pinsonneault et al. 2018
#Reading in the table, making sure all the tables have a column named Age in Gyr
# and that every star in the table has an Age
apokasc2raw = Table.read("Pinsonneault2018.txt", format="ascii.cds")
apokasc2raw['Age']=(10**np.array(apokasc2raw['LogAge'])/1000) #Age was in log(Myr) so needs converting
hasagea2=np.where((apokasc2raw['Age']==apokasc2raw['Age']) & (apokasc2raw['Age']>0.1))
agedata=apokasc2raw[hasagea2]

# %%
from tensorflow import keras

# %%
filename='astraAllStarASPCAP-0.6.0.fits'
tb = fits.open(filename)
header=tb[2].header
data = tb[2].data 

mask_gaia = (data['zgr_plx']>0)
data_masked=data[mask_gaia]

intersect, ind_a, ind_b = np.intersect1d(data_masked['sdss4_apogee_id'],agedata['2MASS'], return_indices=True) 

fullx = np.dstack([data_masked['teff'][ind_a],data_masked['logg'][ind_a], data_masked['m_h_atm'][ind_a],
                   data_masked['alpha_m_atm'][ind_a], data_masked['c_h'][ind_a], data_masked['n_h'][ind_a]])[0]

fully = np.dstack([agedata['Age'][ind_b]])[0] #for Pinsonneault 2018

#remove non-finite entries!
mask = np.all(np.isfinite(fullx), axis=1) & np.all(np.isfinite(fully), axis=1)
fullx, fully = fullx[mask], fully[mask]

scaling_x = np.median(fullx, axis=0)
scaling_y = np.median(fully, axis=0)

fullx, fully = fullx/scaling_x, fully/scaling_y

# %%
neurons_per_layer=50
layers=6
iterations=50

# %%
inputs = keras.Input(shape=(6,))

layer1 = keras.layers.Dense(neurons_per_layer, activation='relu')(inputs)
layer2 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer1)
layer3 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer2)
layer4 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer3)
layer5 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer4)
layer6 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer5)

outputs = keras.layers.Dense(1)(layer6)

model = keras.Model(inputs=inputs, outputs=outputs, name='test')

model.summary()
# Out:
# Model: "test"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 6)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 50)                  │             350 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 50)                  │           2,550 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 50)                  │           2,550 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 50)                  │           2,550 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 50)                  │           2,550 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 50)                  │           2,550 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 13,151 (51.37 KB)
#  Trainable params: 13,151 (51.37 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss=keras.losses.MeanSquaredError(), optimizer=keras.optimizers.Adam(), metrics=['accuracy'])

tenpercent=len(agedata['Age'][ind_b])//10 

trainbin=slice(0,-1*tenpercent-1)
testing=slice(-1*tenpercent,-1)

x_train, y_train = fullx[trainbin], fully[trainbin]
x_test, y_test = fullx[testing], fully[testing]

# %%
model.fit(x_train, y_train, epochs=iterations, validation_split=0.05, batch_size=300)
# Out:
# Epoch 1/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 5.5876e-04 - loss: 0.7780 - val_accuracy: 0.0000e+00 - val_loss: 0.4303
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0013 - loss: 0.2159 - val_accuracy: 0.0000e+00 - val_loss: 0.2049
# Epoch 34/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0013 - loss: 0.2153 - val_accuracy: 0.0000e+00 - val_loss: 0.2042
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0013 - loss: 0.2147 - val_accuracy: 0.0000e+00 - val_loss: 0.1956
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0013 - loss: 0.2120 - val_accuracy: 0.0000e+00 - val_loss: 0.2093
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0013 - loss: 0.2147 - val_accuracy: 0.0000e+00 - val_loss: 0.1960
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0013 - loss: 0.2110 - val_accuracy: 0.0000e+00 - val_loss: 0.1976
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0013 - loss: 0.2102 - val_accuracy: 0.0000e+00 - val_loss: 0.1985
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0013 - loss: 0.2182 - val_accuracy: 0.0000e+00 - val_loss: 0.2043
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0013 - loss: 0.2129 - val_accuracy: 0.0000e+00 - val_loss: 0.2016
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0013 - loss: 0.2115 - val_accuracy: 0.0000e+00 - val_loss: 0.2030
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0013 - loss: 0.2056 - val_accuracy: 0.0000e+00 - val_loss: 0.1912
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0013 - loss: 0.2077 - val_accuracy: 0.0000e+00 - val_loss: 0.1964
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0013 - loss: 0.2158 - val_accuracy: 0.0000e+00 - val_loss: 0.2107
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0013 - loss: 0.2065 - val_accuracy: 0.0000e+00 - val_loss: 0.2044
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0013 - loss: 0.2206 - val_accuracy: 0.0000e+00 - val_loss: 0.2054
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0013 - loss: 0.2139 - val_accuracy: 0.0000e+00 - val_loss: 0.2099
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0013 - loss: 0.2134 - val_accuracy: 0.0000e+00 - val_loss: 0.1969
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0013 - loss: 0.2136 - val_accuracy: 0.0000e+00 - val_loss: 0.2059

# %%
predictions = model.predict(x_test)
print(len(predictions))
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 651

# %%
neurons_per_layer_model2=500
layers_model2=14
iterations_model2=200

# %%
inputs2 = keras.Input(shape=(6,))

layer1model2 = keras.layers.Dense(neurons_per_layer_model2, activation='relu')(inputs2)
layer2model2 = keras.layers.Dense(neurons_per_layer_model2, activation='relu')(layer1model2)
layer3model2 = keras.layers.Dense(neurons_per_layer_model2, activation='relu')(layer2model2)
layer4model2 = keras.layers.Dense(neurons_per_layer_model2, activation='relu')(layer3model2)
layer5model2 = keras.layers.Dense(neurons_per_layer_model2, activation='relu')(layer4model2)
layer6model2 = keras.layers.Dense(neurons_per_layer_model2, activation='relu')(layer5model2)
layer7model2 = keras.layers.Dense(neurons_per_layer_model2, activation='relu')(layer6model2)
layer8model2 = keras.layers.Dense(neurons_per_layer_model2, activation='relu')(layer7model2)
layer9model2 = keras.layers.Dense(neurons_per_layer_model2, activation='relu')(layer8model2)
layer10model2 = keras.layers.Dense(neurons_per_layer_model2, activation='relu')(layer9model2)
layer11model2 = keras.layers.Dense(neurons_per_layer_model2, activation='relu')(layer10model2)
layer12model2 = keras.layers.Dense(neurons_per_layer_model2, activation='relu')(layer11model2)
layer13model2 = keras.layers.Dense(neurons_per_layer_model2, activation='relu')(layer12model2)
layer14model2 = keras.layers.Dense(neurons_per_layer_model2, activation='relu')(layer13model2)

outputs2 = keras.layers.Dense(1)(layer14model2)

model2 = keras.Model(inputs=inputs2, outputs=outputs2, name='second_model')

model2.summary()
# Out:
# Model: "second_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 6)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 500)                 │           3,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 500)                 │         250,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 500)                 │         250,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 500)                 │         250,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 500)                 │         250,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 500)                 │         250,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 500)                 │         250,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 500)                 │         250,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 500)                 │         250,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 500)                 │         250,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 500)                 │         250,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 500)                 │         250,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 500)                 │         250,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 500)                 │         250,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_21 (Dense)                     │ (None, 1)                   │             501 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,260,501 (12.44 MB)
#  Trainable params: 3,260,501 (12.44 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model2.compile(loss=keras.losses.MeanSquaredError(), optimizer=keras.optimizers.Adam(), metrics=['accuracy'])
model2.fit(x_train, y_train, epochs=iterations_model2, validation_split=0.05, batch_size=300)
# Out:
# Epoch 1/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 5.5876e-04 - loss: 1.4035 - val_accuracy: 0.0000e+00 - val_loss: 0.4178
# Epoch 2/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.0013 - loss: 0.4020 - val_accuracy: 0.0000e+00 - val_loss: 0.3137
# Epoch 3/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.0013 - loss: 0.3209 - val_accuracy: 0.0000e+00 - val_loss: 0.2401
# Epoch 4/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.0013 - loss: 0.2714 - val_accuracy: 0.0000e+00 - val_loss: 0.2376
# Epoch 5/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.0013 - loss: 0.2563 - val_accuracy: 0.0000e+00 - val_loss: 0.2302
# Epoch 6/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.0013 - loss: 0.2465 - val_accuracy: 0.0000e+00 - val_loss: 0.2219
# Epoch 7/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.0013 - loss: 0.2341 - val_accuracy: 0.0000e+00 - val_loss: 0.2290
# Epoch 8/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.0013 - loss: 0.2379 - val_accuracy: 0.0000e+00 - val_loss: 0.2288
# Epoch 9/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.0013 - loss: 0.2382 - val_accuracy: 0.0000e+00 - val_loss: 0.2086
# Epoch 10/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.0013 - loss: 0.2336 - val_accuracy: 0.0000e+00 - val_loss: 0.2176
# Epoch 11/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.0013 - loss: 0.2384 - val_accuracy: 0.0000e+00 - val_loss: 0.2229
# Epoch 12/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.0013 - loss: 0.2261 - val_accuracy: 0.0000e+00 - val_loss: 0.2105
# Epoch 13/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.0013 - loss: 0.2369 - val_accuracy: 0.0000e+00 - val_loss: 0.2318
# Epoch 14/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.0013 - loss: 0.2459 - val_accuracy: 0.0000e+00 - val_loss: 0.2142
# Epoch 15/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.0013 - loss: 0.1204 - val_accuracy: 0.0000e+00 - val_loss: 0.1673
# Epoch 177/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.0013 - loss: 0.1226 - val_accuracy: 0.0000e+00 - val_loss: 0.2029
# Epoch 178/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.0013 - loss: 0.1230 - val_accuracy: 0.0000e+00 - val_loss: 0.1486
# Epoch 179/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.0013 - loss: 0.1189 - val_accuracy: 0.0000e+00 - val_loss: 0.1707
# Epoch 180/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - accuracy: 0.0013 - loss: 0.1214 - val_accuracy: 0.0000e+00 - val_loss: 0.1653
# Epoch 181/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.0013 - loss: 0.1460 - val_accuracy: 0.0000e+00 - val_loss: 0.1741
# Epoch 182/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.0013 - loss: 0.1270 - val_accuracy: 0.0000e+00 - val_loss: 0.1387
# Epoch 183/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.0013 - loss: 0.1428 - val_accuracy: 0.0000e+00 - val_loss: 0.1591
# Epoch 184/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.0013 - loss: 0.1480 - val_accuracy: 0.0000e+00 - val_loss: 0.2460
# Epoch 185/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.0013 - loss: 0.1521 - val_accuracy: 0.0000e+00 - val_loss: 0.1901
# Epoch 186/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 0.0013 - loss: 0.1410 - val_accuracy: 0.0000e+00 - val_loss: 0.1803
# Epoch 187/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.0013 - loss: 0.1347 - val_accuracy: 0.0000e+00 - val_loss: 0.1678
# Epoch 188/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.0013 - loss: 0.1224 - val_accuracy: 0.0000e+00 - val_loss: 0.1829
# Epoch 189/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.0013 - loss: 0.1368 - val_accuracy: 0.0000e+00 - val_loss: 0.1660
# Epoch 190/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.0013 - loss: 0.1254 - val_accuracy: 0.0000e+00 - val_loss: 0.1539
# Epoch 191/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.0013 - loss: 0.1273 - val_accuracy: 0.0000e+00 - val_loss: 0.2022
# Epoch 192/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.0013 - loss: 0.1178 - val_accuracy: 0.0000e+00 - val_loss: 0.1772
# Epoch 193/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.0013 - loss: 0.1247 - val_accuracy: 0.0000e+00 - val_loss: 0.1626
# Epoch 194/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.0013 - loss: 0.1170 - val_accuracy: 0.0000e+00 - val_loss: 0.1942
# Epoch 195/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.0013 - loss: 0.1131 - val_accuracy: 0.0000e+00 - val_loss: 0.1799
# Epoch 196/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.0013 - loss: 0.1147 - val_accuracy: 0.0000e+00 - val_loss: 0.1846
# Epoch 197/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.0013 - loss: 0.1242 - val_accuracy: 0.0000e+00 - val_loss: 0.1674
# Epoch 198/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.0013 - loss: 0.1141 - val_accuracy: 0.0000e+00 - val_loss: 0.1795
# Epoch 199/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.0013 - loss: 0.1146 - val_accuracy: 0.0000e+00 - val_loss: 0.1866
# Epoch 200/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.0013 - loss: 0.1148 - val_accuracy: 0.0000e+00 - val_loss: 0.1742

# %%
predictions2 = model2.predict(x_test)
print(len(predictions2))
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 651

# %%
metric=0.3 #is the accuracy better than 30%?
goodfit=np.where(((1-metric) < predictions/y_test) & ((1+metric) > predictions/y_test)) 
badfit=np.where(((1-metric) > predictions/y_test) | ((1+metric) < predictions/y_test))

print ('With ', neurons_per_layer, 'neurons per layer, ', layers, 'layers, and ', iterations, 'iterations')
print ('using the training set', trainbin)
print (len(goodfit[0])/len(y_test)*100, 'percent of the ages are good')
print (len(badfit[0])/len(y_test)*100, 'percent of the ages are bad')
# Out:
# With  50 neurons per layer,  6 layers, and  50 iterations
# using the training set slice(0, -653, None)
# 55.4531490015361 percent of the ages are good
# 44.5468509984639 percent of the ages are bad

# %%
goodfit2=np.where(((1-metric) < predictions2/y_test) & ((1+metric) > predictions2/y_test)) 
badfit2=np.where(((1-metric) > predictions2/y_test) | ((1+metric) < predictions2/y_test))

print ('With ', neurons_per_layer_model2, 'neurons per layer, ', layers_model2, 'layers, and ', iterations_model2, 'iterations')
print ('using the training set', trainbin)
print (len(goodfit2[0])/len(y_test)*100, 'percent of the ages are good')
print (len(badfit2[0])/len(y_test)*100, 'percent of the ages are bad')
# Out:
# With  500 neurons per layer,  14 layers, and  200 iterations
# using the training set slice(0, -653, None)
# 59.754224270353305 percent of the ages are good
# 40.2457757296467 percent of the ages are bad

# %%
difference = abs(predictionsDR19-predictionsDR19_model2)
print(difference)

from astropy.table import QTable
import astropy.units as u

totaldata = Table([predictionsDR19, predictionsDR19_model2, difference], names=('Model 1 Predictions (Gyr)','Model 2 Predictions (Gyr)','Difference (Gyr)'), meta={'name': 'first table'})
print(totaldata)

print("The average difference is",np.mean(difference),"Gyr")
# Out:
# [[0.03370363]
#  [0.02525651]
#  [0.07643248]
#  ...
#  [0.26571125]
#  [0.3022039 ]
#  [0.16721952]]
# Model 1 Predictions (Gyr) Model 2 Predictions (Gyr) Difference (Gyr)
# ------------------------- ------------------------- ----------------
#                 0.5916387                 0.6253423      0.033703625
#                0.66297364                0.68823016      0.025256515
#                0.14987691                0.22630939       0.07643248
#                 0.5634053                0.60409355      0.040688276
#                 1.7646801                 3.1383202        1.3736401
#                 1.8265635                  2.030137       0.20357358
#                 1.8452245                 1.7386026       0.10662186
#                 1.8028697                 2.9025457         1.099676
#                0.84224653                  0.423555       0.41869155
#                  1.454448                 1.7160149       0.26156688
#                 1.9059784                 1.9606516      0.054673195
#                 1.3123059                 0.8970485       0.41525745
#                  0.371257                0.44896442       0.07770741
#                       ...                       ...              ...
#                 1.7646801                 3.1383202        1.3736401
#                 1.7646801                 3.1383202        1.3736401
#                 1.7646801                 3.1383202        1.3736401
#                  2.091817                 2.6985066        0.6066897
#                  5.381659                 2.4009197        2.9807394
#                0.84629816                 1.9162186        1.0699205
#                 1.4382647                  1.072463        0.3658017
#                 2.0177045                 3.1857357        1.1680312
#                 1.4792448                 1.2583369       0.22090793
#                 1.7646801                 3.1383202        1.3736401
#                0.40297222                0.66868347       0.26571125
#                 1.4193281                 1.1171242        0.3022039
#                 1.6071291                 1.7743486       0.16721952
# Length = 963539 rows
# The average difference is 0.61956465 Gyr

# %%
totaldata.write("APOKASC2 trained on 2 different neural models.ecsv")
